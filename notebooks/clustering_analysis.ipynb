# %% [markdown]
# # manueverMotifs: results analysis
# ## Driver D6 - Lateral acceleration
#
# ### 04/10/2019
#
# ***
#
# **Contents**
#
# 1. [Setup](#section1)
# 2. [Load motifs](#section2)
# 3. [DBSCAN clustering](#section3)
#
# ***

# %% [markdown]
# <a id='section1'></a>
# ## 1. Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import time
import pickle
import pandas as pd
import numpy as np
from sklearn.cluster import DBSCAN

# local code
import sys
import os
sys.path.insert(0, os.path.abspath('../scripts'))
import uah_utils
import motif_utils
import lat_viz
import lon_viz

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
cwd = os.getcwd()
data_folder = os.path.abspath(os.path.join(cwd, os.pardir, os.pardir, 'data-uah/D6'))
output_folder = os.path.abspath(os.path.join(cwd, os.pardir, 'data-motifs'))

min_samples = 15
eps = 0.1/2
freq_per_second=10

driver_df = uah_utils.get_full_point_uah_data(data_folder, freq_per_second)

# %% [markdown]
# <a id='section2'></a>
# ## 2. Lateral acceleration
#
# ### Aggressive trip

# %%
trip_id = "20151221120051"
trip_df = driver_df[driver_df['trip_id'] == trip_id].reset_index(drop=True)
ts = trip_df['ay'].values

file_name = "motif_lat_" + trip_df["trip_label"][0] + "_" + trip_df["road"][0] + ".p"
motif_dic_list = pickle.load(open(os.path.join(output_folder, file_name), 'rb'))

file_name = "dist_lat_" + trip_df["trip_label"][0] + "_" + trip_df["road"][0] + ".npy"
center_dist_mat = np.load(open(os.path.join(output_folder, file_name), 'rb'))
    
dbscan_model = DBSCAN(eps=eps, min_samples=min_samples, metric='precomputed').fit(center_dist_mat)
cluster_labels = dbscan_model.labels_
set(cluster_labels)
# Out:
# {-1, 0}

# %%
lat_viz.plot_all_clusters(trip_df, motif_dic_list, cluster_labels)

# %% [markdown]
# ### Drowsy trip

# %%
trip_id = "20151217164730"
trip_df = driver_df[driver_df['trip_id'] == trip_id].reset_index(drop=True)
ts = trip_df['ay'].values

file_name = "motif_lat_" + trip_df["trip_label"][0] + "_" + trip_df["road"][0] + ".p"
motif_dic_list = pickle.load(open(os.path.join(output_folder, file_name), 'rb'))

file_name = "dist_lat_" + trip_df["trip_label"][0] + "_" + trip_df["road"][0] + ".npy"
center_dist_mat = np.load(open(os.path.join(output_folder, file_name), 'rb'))
    
dbscan_model = DBSCAN(eps=eps, min_samples=min_samples, metric='precomputed').fit(center_dist_mat)
cluster_labels = dbscan_model.labels_
set(cluster_labels)
# Out:
# {-1, 0, 1, 2, 3, 4}

# %%
lat_viz.plot_all_clusters(trip_df, motif_dic_list, cluster_labels)

# %% [markdown]
# ### Normal trip

# %%
trip_id = "20151217162714"
trip_df = driver_df[driver_df['trip_id'] == trip_id].reset_index(drop=True)
ts = trip_df['ay'].values

file_name = "motif_lat_" + trip_df["trip_label"][0] + "_" + trip_df["road"][0] + ".p"
motif_dic_list = pickle.load(open(os.path.join(output_folder, file_name), 'rb'))

file_name = "dist_lat_" + trip_df["trip_label"][0] + "_" + trip_df["road"][0] + ".npy"
center_dist_mat = np.load(open(os.path.join(output_folder, file_name), 'rb'))
    
dbscan_model = DBSCAN(eps=eps, min_samples=min_samples, metric='precomputed').fit(center_dist_mat)
cluster_labels = dbscan_model.labels_
set(cluster_labels)
# Out:
# {-1, 0, 1, 2, 3, 4, 5}

# %%
lat_viz.plot_all_clusters(trip_df, motif_dic_list, cluster_labels)

# %% [markdown]
# ### Secondary road trip

# %%
trip_id = "20151221112434"
trip_df = driver_df[driver_df['trip_id'] == trip_id].reset_index(drop=True)
ts = trip_df['ay'].values

file_name = "motif_lat_" + trip_df["trip_label"][0] + "_" + trip_df["road"][0] + ".p"
motif_dic_list = pickle.load(open(os.path.join(output_folder, file_name), 'rb'))

file_name = "dist_lat_" + trip_df["trip_label"][0] + "_" + trip_df["road"][0] + ".npy"
center_dist_mat = np.load(open(os.path.join(output_folder, file_name), 'rb'))
    
dbscan_model = DBSCAN(eps=eps, min_samples=min_samples, metric='precomputed').fit(center_dist_mat)
cluster_labels = dbscan_model.labels_
set(cluster_labels)
# Out:
# {-1, 0, 1}

# %%
lat_viz.plot_all_clusters(trip_df, motif_dic_list, cluster_labels)

# %% [markdown]
# <a id='section3'></a>
# ## 3. Longitudinal acceleration
#
# ### Aggressive trip

# %%
trip_id = "20151221120051"
trip_df = driver_df[driver_df['trip_id'] == trip_id].reset_index(drop=True)
ts = trip_df['az'].values

file_name = "motif_lon_" + trip_df["trip_label"][0] + "_" + trip_df["road"][0] + ".p"
motif_dic_list = pickle.load(open(os.path.join(output_folder, file_name), 'rb'))

file_name = "dist_lon_" + trip_df["trip_label"][0] + "_" + trip_df["road"][0] + ".npy"
center_dist_mat = np.load(open(os.path.join(output_folder, file_name), 'rb'))
    
dbscan_model = DBSCAN(eps=eps, min_samples=min_samples, metric='precomputed').fit(center_dist_mat)
cluster_labels = dbscan_model.labels_
set(cluster_labels)
# Out:
# {-1, 0, 1, 2, 3, 4, 5, 6, 7}

# %%
lon_viz.plot_all_clusters(trip_df, motif_dic_list, cluster_labels)

# %% [markdown]
# ### Drowsy trip

# %%
trip_id = "20151217164730"
trip_df = driver_df[driver_df['trip_id'] == trip_id].reset_index(drop=True)
ts = trip_df['az'].values

file_name = "motif_lon_" + trip_df["trip_label"][0] + "_" + trip_df["road"][0] + ".p"
motif_dic_list = pickle.load(open(os.path.join(output_folder, file_name), 'rb'))

file_name = "dist_lon_" + trip_df["trip_label"][0] + "_" + trip_df["road"][0] + ".npy"
center_dist_mat = np.load(open(os.path.join(output_folder, file_name), 'rb'))
    
dbscan_model = DBSCAN(eps=eps, min_samples=min_samples, metric='precomputed').fit(center_dist_mat)
cluster_labels = dbscan_model.labels_
set(cluster_labels)
# Out:
# {-1, 0, 1, 2, 3, 4}

# %%
lon_viz.plot_all_clusters(trip_df, motif_dic_list, cluster_labels)

# %% [markdown]
# ### Normal trip

# %%
trip_id = "20151217162714"
trip_df = driver_df[driver_df['trip_id'] == trip_id].reset_index(drop=True)
ts = trip_df['az'].values

file_name = "motif_lon_" + trip_df["trip_label"][0] + "_" + trip_df["road"][0] + ".p"
motif_dic_list = pickle.load(open(os.path.join(output_folder, file_name), 'rb'))

file_name = "dist_lon_" + trip_df["trip_label"][0] + "_" + trip_df["road"][0] + ".npy"
center_dist_mat = np.load(open(os.path.join(output_folder, file_name), 'rb'))
    
dbscan_model = DBSCAN(eps=eps, min_samples=min_samples, metric='precomputed').fit(center_dist_mat)
cluster_labels = dbscan_model.labels_
set(cluster_labels)
# Out:
# {-1, 0, 1, 2, 3, 4}

# %%
lon_viz.plot_all_clusters(trip_df, motif_dic_list, cluster_labels)

# %% [markdown]
# ### Secondary road trip

# %%
trip_id = "20151221112434"
trip_df = driver_df[driver_df['trip_id'] == trip_id].reset_index(drop=True)
ts = trip_df['az'].values

file_name = "motif_lon_" + trip_df["trip_label"][0] + "_" + trip_df["road"][0] + ".p"
motif_dic_list = pickle.load(open(os.path.join(output_folder, file_name), 'rb'))

file_name = "dist_lon_" + trip_df["trip_label"][0] + "_" + trip_df["road"][0] + ".npy"
center_dist_mat = np.load(open(os.path.join(output_folder, file_name), 'rb'))
    
dbscan_model = DBSCAN(eps=eps, min_samples=min_samples, metric='precomputed').fit(center_dist_mat)
cluster_labels = dbscan_model.labels_
set(cluster_labels)
# Out:
# {-1, 0, 1}

# %%
lon_viz.plot_all_clusters(trip_df, motif_dic_list, cluster_labels)
